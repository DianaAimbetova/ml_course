# %%
start_number = int(input("Please enter an number: "))
def Fibonacci(n): 
    if n<0: 
        print("Incorrect input") 
    # First Fibonacci number is 0 
    elif n==1: 
        return 0
    # Second Fibonacci number is 1 
    elif n==2: 
        return 1
    else: 
        return Fibonacci(n-1)+Fibonacci(n-2) 
    
print(Fibonacci(start_number))
# Out:
# Please enter an number: 3
# 1

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
df_train = {}
df_train['Возраст'] = [17,18,20,25,29,31,33,38,49,55,64] 
df_train['Невозврат кредита'] = [1,1,0,1,1,0,1,1,0,0,0]
df_train['Зарплата'] =[25,22,36,70,33,102,88,37,59,74,80]
data = pd.DataFrame(df_train)

# %%
age_tree = DecisionTreeClassifier(random_state=17)
age_tree.fit(data[['Возраст','Зарплата']].values, data['Невозврат кредита'].values)

export_graphviz(age_tree, feature_names=['Возраст','Зарплата'], out_file='../../img/age_tree2.dot', filled=True)
# !dot -Tpng ../../img/age_tree2.dot -o ../../img/age_tree2.png

# %%
from IPython.display import Image
Image(filename='../../img/age_tree2.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(df_train['Возраст'], df_train['Невозврат кредита']);

# %%
def form_linearly_separable_data(n=5, x1_min=0, x1_max=30, x2_min=0, x2_max=30):
    data, target = [], []
    for i in range(n):
        x1, x2 = np.random.randint(x1_min, x1_max), np.random.randint(x2_min, x2_max)

        if np.abs(x1 - x2) > 0.5:
            data.append([x1, x2])
            target.append(np.sign(x1 - x2))
    return np.array(data), np.array(target)

X, y = form_linearly_separable_data()
print(X,y)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='autumn', edgecolors='black');
# Out:
# [[27 24]
#  [ 7  5]
#  [25 26]
#  [ 6 12]
#  [21 20]] [ 1  1 -1 -1  1]
